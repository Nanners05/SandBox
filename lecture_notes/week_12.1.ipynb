# %%
# Dictionary

person = {"Name": "Aidan", "Age": 22, "Fav_color": "Green"}
person["Name"]
# Out:
# 'Green'

# %%
stock = {"ticker": {"Name":"AAPL", "Price": 100}}
stock["ticker"]
# Out:
# {'Name': 'AAPL', 'Price': 100}

# %%
stock["ticker"]["Price"]
# Out:
# 100

# %%
# Keys
person.keys()
# Out:
# dict_keys(['Name', 'Age', 'Fav_color'])

# %%
# CRUD

#Create
sodas = {}
sodas["Soda_Name"] = {"Name": "Fresca", "Name2": "Coke"}

#Update
# Out:
# {'Soda_Name': 'Fresca'}

# %%
#2D lists

numbers = [
    [1,2,3],
    [4,5,6]
]
numbers[1][2]
# Out:
# 6
